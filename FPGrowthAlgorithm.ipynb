# %%
# Step 1: Import Libraries
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules

# %%
# Step 2: Manually Define 5 Transactions
transactions = [
    ['young', 'myope', 'no', 'reduced', 'none'],
    ['young', 'myope', 'no', 'normal', 'soft'],
    ['young', 'hypermetrope', 'no', 'normal', 'soft'],
    ['pre-presbyopic', 'myope', 'yes', 'normal', 'hard'],
    ['presbyopic', 'hypermetrope', 'yes', 'normal', 'none']
]

# %%
# Step 3: Convert Transactions into One-Hot Encoding
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_array, columns=te.columns_)
print("One-Hot Encoded Dataset:")
print(df)
# Out:
# One-Hot Encoded Dataset:
#     hard  hypermetrope  myope     no   none  normal  pre-presbyopic  \
# 0  False         False   True   True   True   False           False
# 1  False         False   True   True  False    True           False
# 2  False          True  False   True  False    True           False
# 3   True         False   True  False  False    True            True
# 4  False          True  False  False   True    True           False
#
#    presbyopic  reduced   soft    yes  young
# 0       False     True  False  False   True
# 1       False    False   True  False   True
# 2       False    False   True  False   True
# 3       False    False  False   True  False
# 4        True    False  False   True  False

# %%
# Step 4: Apply FP-Growth
frequent_itemsets = fpgrowth(df, min_support=0.4, use_colnames=True)

print("\nFrequent Itemsets:")
print(frequent_itemsets)
# Out:
# Frequent Itemsets:
#     support                   itemsets
# 0       0.6                    (young)
# 1       0.6                       (no)
# 2       0.6                    (myope)
# 3       0.4                     (none)
# 4       0.8                   (normal)
# 5       0.4                     (soft)
# 6       0.4             (hypermetrope)
# 7       0.4                      (yes)
# 8       0.4            (young, normal)
# 9       0.6                (young, no)
# 10      0.4               (no, normal)
# 11      0.4        (young, no, normal)
# 12      0.4                (myope, no)
# 13      0.4             (myope, young)
# 14      0.4            (myope, normal)
# 15      0.4         (myope, young, no)
# 16      0.4                 (soft, no)
# 17      0.4              (soft, young)
# 18      0.4             (soft, normal)
# 19      0.4          (soft, young, no)
# 20      0.4         (soft, no, normal)
# 21      0.4      (soft, young, normal)
# 22      0.4  (soft, young, no, normal)
# 23      0.4     (hypermetrope, normal)
# 24      0.4              (yes, normal)

# %%
# Step 5: Generate Association Rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

print("\nAssociation Rules:")
print(rules)
# Out:
# Association Rules:
#               antecedents            consequents  antecedent support  \
# 0                 (young)               (normal)                 0.6
# 1                 (young)                   (no)                 0.6
# 2                    (no)                (young)                 0.6
# 3                    (no)               (normal)                 0.6
# 4             (young, no)               (normal)                 0.6
# 5         (young, normal)                   (no)                 0.4
# 6            (no, normal)                (young)                 0.4
# 7                 (young)           (no, normal)                 0.6
# 8                    (no)        (young, normal)                 0.6
# 9                 (myope)                   (no)                 0.6
# 10                   (no)                (myope)                 0.6
# 11                (myope)                (young)                 0.6
# 12                (young)                (myope)                 0.6
# 13                (myope)               (normal)                 0.6
# 14         (myope, young)                   (no)                 0.4
# 15            (myope, no)                (young)                 0.4
# 16            (young, no)                (myope)                 0.6
# 17                (myope)            (young, no)                 0.6
# 18                (young)            (myope, no)                 0.6
# 19                   (no)         (myope, young)                 0.6
# 20                 (soft)                   (no)                 0.4
# 21                   (no)                 (soft)                 0.6
# 22                 (soft)                (young)                 0.4
# 23                (young)                 (soft)                 0.6
# 24                 (soft)               (normal)                 0.4
# 25          (soft, young)                   (no)                 0.4
# 26             (soft, no)                (young)                 0.4
# 27            (young, no)                 (soft)                 0.6
# 28                 (soft)            (young, no)                 0.4
# 29                (young)             (soft, no)                 0.6
# 30                   (no)          (soft, young)                 0.6
# 31             (soft, no)               (normal)                 0.4
# 32         (soft, normal)                   (no)                 0.4
# 33           (no, normal)                 (soft)                 0.4
# 34                 (soft)           (no, normal)                 0.4
# 35                   (no)         (soft, normal)                 0.6
# 36          (soft, young)               (normal)                 0.4
# 37         (soft, normal)                (young)                 0.4
# 38        (young, normal)                 (soft)                 0.4
# 39                 (soft)        (young, normal)                 0.4
# 40                (young)         (soft, normal)                 0.6
# 41      (soft, young, no)               (normal)                 0.4
# 42  (soft, young, normal)                   (no)                 0.4
# 43     (soft, no, normal)                (young)                 0.4
# 44    (young, no, normal)                 (soft)                 0.4
# 45          (soft, young)           (no, normal)                 0.4
# 46             (soft, no)        (young, normal)                 0.4
# 47         (soft, normal)            (young, no)                 0.4
# 48            (young, no)         (soft, normal)                 0.6
# 49        (young, normal)             (soft, no)                 0.4
# 50           (no, normal)          (soft, young)                 0.4
# 51                 (soft)    (young, no, normal)                 0.4
# 52                (young)     (soft, no, normal)                 0.6
# 53                   (no)  (soft, young, normal)                 0.6
# 54         (hypermetrope)               (normal)                 0.4
# 55                  (yes)               (normal)                 0.4
#
#     consequent support  support  confidence      lift  representativity  \
# 0                  0.8      0.4    0.666667  0.833333               1.0
# 1                  0.6      0.6    1.000000  1.666667               1.0
# 2                  0.6      0.6    1.000000  1.666667               1.0
# 3                  0.8      0.4    0.666667  0.833333               1.0
# 4                  0.8      0.4    0.666667  0.833333               1.0
# 5                  0.6      0.4    1.000000  1.666667               1.0
# 6                  0.6      0.4    1.000000  1.666667               1.0
# 7                  0.4      0.4    0.666667  1.666667               1.0
# 8                  0.4      0.4    0.666667  1.666667               1.0
# 9                  0.6      0.4    0.666667  1.111111               1.0
# 10                 0.6      0.4    0.666667  1.111111               1.0
# 11                 0.6      0.4    0.666667  1.111111               1.0
# 12                 0.6      0.4    0.666667  1.111111               1.0
# 13                 0.8      0.4    0.666667  0.833333               1.0
# 14                 0.6      0.4    1.000000  1.666667               1.0
# 15                 0.6      0.4    1.000000  1.666667               1.0
# 16                 0.6      0.4    0.666667  1.111111               1.0
# 17                 0.6      0.4    0.666667  1.111111               1.0
# 18                 0.4      0.4    0.666667  1.666667               1.0
# 19                 0.4      0.4    0.666667  1.666667               1.0
# 20                 0.6      0.4    1.000000  1.666667               1.0
